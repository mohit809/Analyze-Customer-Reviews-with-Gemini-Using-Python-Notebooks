# %% [markdown]
# # Example 1: Query a table with SQL and magic commands

# %%
# Import Python libraries
import vertexai
from vertexai.generative_models import GenerativeModel, Part
from google.cloud import bigquery
from google.cloud import storage
import json
import io
import matplotlib.pyplot as plt
from IPython.display import HTML, display
from IPython.display import Audio
from pprint import pprint

# %%
# Set Python variables for project_id and region
project_id = "qwiklabs-gcp-02-5c9e576b4dbf"
region = " us-central1"

# %%
# Create the resource connection
# !bq mk --connection \
  --connection_type=CLOUD_RESOURCE \
  --location=US \
  gemini_conn
# Out:
# BigQuery error in mk operation: Already Exists: Connection
# projects/670589178564/locations/us/connections/gemini_conn

# %%
# Create the dataset
# %%bigquery
CREATE SCHEMA IF NOT EXISTS `qwiklabs-gcp-02-5c9e576b4dbf.gemini_demo`
OPTIONS(location="US");
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Create the customer reviews table
# %%bigquery
LOAD DATA OVERWRITE gemini_demo.customer_reviews
(customer_review_id INT64, customer_id INT64, location_id INT64, review_datetime DATETIME, review_text STRING, social_media_source STRING, social_media_handle STRING)
FROM FILES (
  format = 'CSV',
  uris = ['gs://qwiklabs-gcp-02-5c9e576b4dbf-bucket/gsp1249/customer_reviews.csv']);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Create the customer reviews table
# %%bigquery
SELECT * FROM `gemini_demo.customer_reviews`
ORDER BY review_datetime
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     customer_review_id  customer_id  location_id     review_datetime  \
# 0                 5499         3383            1 2024-01-01 22:36:10
# 1                 1711         9574            1 2024-01-07 19:58:10
# 2                 2339         5640            1 2024-01-10 00:05:10
# 3                 4316         3309            1 2024-01-13 12:22:10
# 4                  995         8206            1 2024-01-16 20:00:10
# 5                 6818         4557            1 2024-01-24 04:24:10
# 6                 7835         5511            1 2024-01-28 23:27:10
# 7                 5484         8452            1 2024-02-05 15:41:10
# 8                 5006         3174            1 2024-02-05 18:02:10
# 9                 5487         2909            1 2024-02-06 10:23:10
# 10                3998         8844            1 2024-02-12 09:03:10
# 11                5731         6206            1 2024-02-15 21:02:10
# 12                3215         7091            1 2024-02-18 07:00:10
# 13                4457         8704            1 2024-03-08 05:29:10
# 14                3401         6470            1 2024-03-10 07:42:10
# 15                4478         4364            1 2024-03-10 23:41:10
# 16                1612         8088            1 2024-03-27 04:15:10
# 17                7796         5980            1 2024-03-27 22:44:10
# 18                 188         7159            1 2024-04-07 13:59:10
# 19                7077         6004            1 2024-04-10 00:33:10
# 20                1088         7143            1 2024-04-11 08:15:10
# 21                2933         5576            1 2024-04-18 06:39:10
# 22                 877         3347            1 2024-05-01 14:39:10
# 23                2739         6126            1 2024-05-02 06:35:10
# 24                2949         7664            1 2024-05-02 15:46:10
# 25                 163         3797            1 2024-05-11 21:20:10
# 26                7687         4725            1 2024-05-14 03:09:10
# 27                 260         9464            1 2024-05-15 23:07:10
# 28                5163         7084            1 2024-06-01 11:59:10
# 29                2648         4585            1 2024-06-04 20:26:10
# 30                1339         5634            1 2024-06-07 07:48:10
# 31                3079         4433            1 2024-06-26 10:23:10
# 32                 683         1854            1 2024-07-13 23:57:10
# 33                  85         4034            1 2024-07-25 03:20:10
# 34                1216         6867            1 2024-08-01 07:13:10
# 35                4936        10230            1 2024-08-21 05:10:10
# 36                6620         8399            1 2024-09-06 15:07:10
# 37                1224         9745            1 2024-09-09 20:26:10
# 38                7822         8118            1 2024-09-16 10:26:10
# 39                7167         3615            1 2024-09-29 13:24:10
# 40                7447         9889            1 2024-10-02 12:17:10
# 41                1680         1080            1 2024-10-15 16:09:10
# 42                 579         3731            1 2024-10-31 03:40:10
# 43                2080         1265            1 2024-11-02 02:17:10
# 44                6093         3498            1 2024-11-10 12:57:10
# 45                7868         7769            1 2024-11-13 00:09:10
# 46                1598         4840            1 2024-11-15 03:47:10
# 47                7704         9432            1 2024-11-26 00:59:10
# 48                7705         2274            1 2024-12-26 11:43:10
# 49                7841         4938            1 2024-12-30 07:02:10
#
#                                           review_text social_media_source  \
# 0   Good service, short wait time for quality coff...             Twitter
# 1   Great atmosphere,  and drinks are always on po...             Twitter
# 2   The wait time was short so I got excellent ser...             Twitter
# 3   The staff was very friendly and the coffee was...            Facebook
# 4   The service could be improved. I think it’s di...              Google
# 5   I had a great experience at this coffee truck....           Instagram
# 6   The customer service was great and the wait ti...            Facebook
# 7   I had a great experience at this coffee truck....            Facebook
# 8                  Good location and delicious coffee            Facebook
# 9   Bad Service.  The staff was rude and unhelpful...             Twitter
# 10  I had a very disappointing experience at this ...              Google
# 11  Delicious coffee!!! They are one of the rare c...         TripAdvisor
# 12  The service was great. The coffee was amazing....            Facebook
# 13  The staff was very friendly and the service wa...            Facebook
# 14  Good service the staff kept the line moving an...            Facebook
# 15  The service was great and the coffee was even ...            Facebook
# 16  Good service. This location is convenient but ...            Facebook
# 17  I was really impressed with the quality of the...             Twitter
# 18  The coffee I ordered was not hot and the perso...             Twitter
# 19  The service at this location was great! The em...            Facebook
# 20  I've been coming to this coffee truck for year...              Google
# 21  The location was clean and inviting. I also li...              Tiktok
# 22                                    Noisy Location'             Twitter
# 23  The coffee was hot, fresh, and delicious. I wo...              Google
# 24  The coffee and snacks were delicious. The cozy...             Twitter
# 25  The coffee was too bitter and weak. I will not...             Twitter
# 26  Great coffee, friendly staff, and a cozy atmos...              Google
# 27  Great coffee and friendly staff, will definite...            Facebook
# 28  Great coffee, friendly staff.  I usually get t...           Instagram
# 29  service was fast even during peak hours.  comf...             Twitter
# 30  I enjoyed my fresh brewed coffee.  The barista...            Facebook
# 31  The service at this location was great. The st...            Facebook
# 32  Good service with a short wait time. The coffe...           Instagram
# 33  The coffee was too strong for my taste and it ...             Twitter
# 34  I had a great experience at this coffee truck....            Facebook
# 35  The cozy seating areas and quiet location prov...           Instagram
# 36  I had a great experience at this location! The...            Facebook
# 37  The baristas were incredibly rude to me for no...             Twitter
# 38  The coffee was ok but the atmosphere was so re...           Instagram
# 39  I had a great experience at this coffee truck....            Facebook
# 40  I was very impressed with the cozy seating are...              Google
# 41  Very friendly and knowledgeable staff, cozy at...              Google
# 42  I had a great experience today! The barista wa...             Twitter
# 43  Great coffee, friendly staff a bit of a wait (...           Instagram
# 44                                       Great coffee            Facebook
# 45  Bad service and very overpriced. They seemed v...                Yelp
# 46  The coffee is strong and flavorful and the sta...              Google
# 47  I had a great experience at this coffee truck....             Twitter
# 48  This coffee truck is amazing! The staff are al...            Facebook
# 49  Great coffee, friendly staff, and cozy atmosph...           Instagram
#
#        social_media_handle
# 0                mrs_m_888
# 1          coffee_lover_98
# 2             coffeeholic7
# 3                @joesmith
# 4        coffee_drinker_39
# 5         coffee_lover_123
# 6               johndoe123
# 7              joesmith123
# 8        joe.doe@gmail.com
# 9            not_real_user
# 10            coffee_lover
# 11            @coffee4lyfe
# 12          CoffeeLover123
# 13        coffee_lover_123
# 14         coffee_lover123
# 15              johndoe123
# 16              TheRealBob
# 17           @coffeelover1
# 18          @coffee_critic
# 19                joesmith
# 20           coffeeholic81
# 21              that_coffe
# 22          @coffee_addict
# 23              anonymized
# 24          coffee_lover45
# 25          CoffeeHater101
# 26              @johnsmith
# 27              @joebloggs
# 28        coffee_lover_123
# 29                @joemama
# 30             joan.jones1
# 31               customer1
# 32       customer_username
# 33          @coffeelover95
# 34         coffee_lover_99
# 35          @coffeeholic99
# 36                joesmith
# 37        iced_mocha_lover
# 38           @fancy_coffee
# 39             sampleuser1
# 40         coffee_bean_123
# 41          coffee_fanatic
# 42        coffee_lover_350
# 43  @coffeebean_enthusiast
# 44                 @coffee
# 45               FoodieGuy
# 46              customer_9
# 47         @coffeelover987
# 48         @coffeelover123
# 49          CoffeeLover123

# %%
# Create the sentiment analysis table
# %%bigquery
CREATE OR REPLACE TABLE
`gemini_demo.customer_reviews_analysis` AS (
SELECT ml_generate_text_llm_result, social_media_source, review_text, customer_id, location_id, review_datetime
FROM
ML.GENERATE_TEXT(
MODEL `gemini_demo.gemini_pro`,
(
   SELECT social_media_source, customer_id, location_id, review_text, review_datetime, CONCAT(
      'Classify the sentiment of the following text as positive or negative.',
      review_text, "In your response don't include the sentiment explanation. Remove all extraneous information from your response, it should be a boolean response either positive or negative.") AS prompt
   FROM `gemini_demo.customer_reviews`
),
STRUCT(
   0.2 AS temperature, TRUE AS flatten_json_output)));
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Pull the first 100 records from the customer_reviews_analysis table
# %%bigquery
SELECT * FROM `gemini_demo.customer_reviews_analysis`
ORDER BY review_datetime
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    ml_generate_text_llm_result social_media_source  \
# 0                     positive             Twitter
# 1                     positive             Twitter
# 2                     positive             Twitter
# 3                     positive            Facebook
# 4                     negative              Google
# 5                     positive           Instagram
# 6                     positive            Facebook
# 7                     positive            Facebook
# 8                     positive            Facebook
# 9                     negative             Twitter
# 10                    negative              Google
# 11                    positive         TripAdvisor
# 12                    positive            Facebook
# 13                    positive            Facebook
# 14                    positive            Facebook
# 15                    positive            Facebook
# 16                        None            Facebook
# 17                    Positive             Twitter
# 18                    negative             Twitter
# 19                    positive            Facebook
# 20                    positive              Google
# 21                    Positive              Tiktok
# 22                    negative             Twitter
# 23                    positive              Google
# 24                    positive             Twitter
# 25                    negative             Twitter
# 26                    positive              Google
# 27                    positive            Facebook
# 28                    positive           Instagram
# 29                    positive             Twitter
# 30                        None            Facebook
# 31                    Positive            Facebook
# 32                    positive           Instagram
# 33                    negative             Twitter
# 34                    positive            Facebook
# 35                    positive           Instagram
# 36                    positive            Facebook
# 37                    negative             Twitter
# 38                        None           Instagram
# 39                    positive            Facebook
# 40                    positive              Google
# 41                    positive              Google
# 42                    positive             Twitter
# 43                    positive           Instagram
# 44                    positive            Facebook
# 45                    negative                Yelp
# 46                    positive              Google
# 47                    positive             Twitter
# 48                    positive            Facebook
# 49                    positive           Instagram
#
#                                           review_text  customer_id  \
# 0   Good service, short wait time for quality coff...         3383
# 1   Great atmosphere,  and drinks are always on po...         9574
# 2   The wait time was short so I got excellent ser...         5640
# 3   The staff was very friendly and the coffee was...         3309
# 4   The service could be improved. I think it’s di...         8206
# 5   I had a great experience at this coffee truck....         4557
# 6   The customer service was great and the wait ti...         5511
# 7   I had a great experience at this coffee truck....         8452
# 8                  Good location and delicious coffee         3174
# 9   Bad Service.  The staff was rude and unhelpful...         2909
# 10  I had a very disappointing experience at this ...         8844
# 11  Delicious coffee!!! They are one of the rare c...         6206
# 12  The service was great. The coffee was amazing....         7091
# 13  The staff was very friendly and the service wa...         8704
# 14  Good service the staff kept the line moving an...         6470
# 15  The service was great and the coffee was even ...         4364
# 16  Good service. This location is convenient but ...         8088
# 17  I was really impressed with the quality of the...         5980
# 18  The coffee I ordered was not hot and the perso...         7159
# 19  The service at this location was great! The em...         6004
# 20  I've been coming to this coffee truck for year...         7143
# 21  The location was clean and inviting. I also li...         5576
# 22                                    Noisy Location'         3347
# 23  The coffee was hot, fresh, and delicious. I wo...         6126
# 24  The coffee and snacks were delicious. The cozy...         7664
# 25  The coffee was too bitter and weak. I will not...         3797
# 26  Great coffee, friendly staff, and a cozy atmos...         4725
# 27  Great coffee and friendly staff, will definite...         9464
# 28  Great coffee, friendly staff.  I usually get t...         7084
# 29  service was fast even during peak hours.  comf...         4585
# 30  I enjoyed my fresh brewed coffee.  The barista...         5634
# 31  The service at this location was great. The st...         4433
# 32  Good service with a short wait time. The coffe...         1854
# 33  The coffee was too strong for my taste and it ...         4034
# 34  I had a great experience at this coffee truck....         6867
# 35  The cozy seating areas and quiet location prov...        10230
# 36  I had a great experience at this location! The...         8399
# 37  The baristas were incredibly rude to me for no...         9745
# 38  The coffee was ok but the atmosphere was so re...         8118
# 39  I had a great experience at this coffee truck....         3615
# 40  I was very impressed with the cozy seating are...         9889
# 41  Very friendly and knowledgeable staff, cozy at...         1080
# 42  I had a great experience today! The barista wa...         3731
# 43  Great coffee, friendly staff a bit of a wait (...         1265
# 44                                       Great coffee         3498
# 45  Bad service and very overpriced. They seemed v...         7769
# 46  The coffee is strong and flavorful and the sta...         4840
# 47  I had a great experience at this coffee truck....         9432
# 48  This coffee truck is amazing! The staff are al...         2274
# 49  Great coffee, friendly staff, and cozy atmosph...         4938
#
#     location_id     review_datetime
# 0             1 2024-01-01 22:36:10
# 1             1 2024-01-07 19:58:10
# 2             1 2024-01-10 00:05:10
# 3             1 2024-01-13 12:22:10
# 4             1 2024-01-16 20:00:10
# 5             1 2024-01-24 04:24:10
# 6             1 2024-01-28 23:27:10
# 7             1 2024-02-05 15:41:10
# 8             1 2024-02-05 18:02:10
# 9             1 2024-02-06 10:23:10
# 10            1 2024-02-12 09:03:10
# 11            1 2024-02-15 21:02:10
# 12            1 2024-02-18 07:00:10
# 13            1 2024-03-08 05:29:10
# 14            1 2024-03-10 07:42:10
# 15            1 2024-03-10 23:41:10
# 16            1 2024-03-27 04:15:10
# 17            1 2024-03-27 22:44:10
# 18            1 2024-04-07 13:59:10
# 19            1 2024-04-10 00:33:10
# 20            1 2024-04-11 08:15:10
# 21            1 2024-04-18 06:39:10
# 22            1 2024-05-01 14:39:10
# 23            1 2024-05-02 06:35:10
# 24            1 2024-05-02 15:46:10
# 25            1 2024-05-11 21:20:10
# 26            1 2024-05-14 03:09:10
# 27            1 2024-05-15 23:07:10
# 28            1 2024-06-01 11:59:10
# 29            1 2024-06-04 20:26:10
# 30            1 2024-06-07 07:48:10
# 31            1 2024-06-26 10:23:10
# 32            1 2024-07-13 23:57:10
# 33            1 2024-07-25 03:20:10
# 34            1 2024-08-01 07:13:10
# 35            1 2024-08-21 05:10:10
# 36            1 2024-09-06 15:07:10
# 37            1 2024-09-09 20:26:10
# 38            1 2024-09-16 10:26:10
# 39            1 2024-09-29 13:24:10
# 40            1 2024-10-02 12:17:10
# 41            1 2024-10-15 16:09:10
# 42            1 2024-10-31 03:40:10
# 43            1 2024-11-02 02:17:10
# 44            1 2024-11-10 12:57:10
# 45            1 2024-11-13 00:09:10
# 46            1 2024-11-15 03:47:10
# 47            1 2024-11-26 00:59:10
# 48            1 2024-12-26 11:43:10
# 49            1 2024-12-30 07:02:10

# %%
# Sanitize the records within a new view
# %%bigquery
CREATE OR REPLACE VIEW gemini_demo.cleaned_data_view AS
SELECT REPLACE(REPLACE(LOWER(ml_generate_text_llm_result), '.', ''), ' ', '') AS sentiment,
REGEXP_REPLACE(
      REGEXP_REPLACE(
            REGEXP_REPLACE(social_media_source, r'Google(\+|\sReviews|\sLocal|\sMy\sBusiness|\sreviews|\sMaps)?', 'Google'),
            'YELP', 'Yelp'
      ),
      r'SocialMedia1?', 'Social Media'
   ) AS social_media_source,
review_text, customer_id, location_id, review_datetime
FROM `gemini_demo.customer_reviews_analysis`;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Create the customer reviews table
# %%bigquery
CREATE OR REPLACE MODEL `gemini_demo.gemini_pro`
REMOTE WITH CONNECTION `us.gemini_conn`
OPTIONS (endpoint = 'gemini-pro')
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Pull the first 100 records from the cleaned_data_view view
# %%bigquery
SELECT * FROM `gemini_demo.cleaned_data_view`
ORDER BY review_datetime
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    sentiment social_media_source  \
# 0   positive             Twitter
# 1   positive             Twitter
# 2   positive             Twitter
# 3   positive            Facebook
# 4   negative              Google
# 5   positive           Instagram
# 6   positive            Facebook
# 7   positive            Facebook
# 8   positive            Facebook
# 9   negative             Twitter
# 10  negative              Google
# 11  positive         TripAdvisor
# 12  positive            Facebook
# 13  positive            Facebook
# 14  positive            Facebook
# 15  positive            Facebook
# 16      None            Facebook
# 17  positive             Twitter
# 18  negative             Twitter
# 19  positive            Facebook
# 20  positive              Google
# 21  positive              Tiktok
# 22  negative             Twitter
# 23  positive              Google
# 24  positive             Twitter
# 25  negative             Twitter
# 26  positive              Google
# 27  positive            Facebook
# 28  positive           Instagram
# 29  positive             Twitter
# 30      None            Facebook
# 31  positive            Facebook
# 32  positive           Instagram
# 33  negative             Twitter
# 34  positive            Facebook
# 35  positive           Instagram
# 36  positive            Facebook
# 37  negative             Twitter
# 38      None           Instagram
# 39  positive            Facebook
# 40  positive              Google
# 41  positive              Google
# 42  positive             Twitter
# 43  positive           Instagram
# 44  positive            Facebook
# 45  negative                Yelp
# 46  positive              Google
# 47  positive             Twitter
# 48  positive            Facebook
# 49  positive           Instagram
#
#                                           review_text  customer_id  \
# 0   Good service, short wait time for quality coff...         3383
# 1   Great atmosphere,  and drinks are always on po...         9574
# 2   The wait time was short so I got excellent ser...         5640
# 3   The staff was very friendly and the coffee was...         3309
# 4   The service could be improved. I think it’s di...         8206
# 5   I had a great experience at this coffee truck....         4557
# 6   The customer service was great and the wait ti...         5511
# 7   I had a great experience at this coffee truck....         8452
# 8                  Good location and delicious coffee         3174
# 9   Bad Service.  The staff was rude and unhelpful...         2909
# 10  I had a very disappointing experience at this ...         8844
# 11  Delicious coffee!!! They are one of the rare c...         6206
# 12  The service was great. The coffee was amazing....         7091
# 13  The staff was very friendly and the service wa...         8704
# 14  Good service the staff kept the line moving an...         6470
# 15  The service was great and the coffee was even ...         4364
# 16  Good service. This location is convenient but ...         8088
# 17  I was really impressed with the quality of the...         5980
# 18  The coffee I ordered was not hot and the perso...         7159
# 19  The service at this location was great! The em...         6004
# 20  I've been coming to this coffee truck for year...         7143
# 21  The location was clean and inviting. I also li...         5576
# 22                                    Noisy Location'         3347
# 23  The coffee was hot, fresh, and delicious. I wo...         6126
# 24  The coffee and snacks were delicious. The cozy...         7664
# 25  The coffee was too bitter and weak. I will not...         3797
# 26  Great coffee, friendly staff, and a cozy atmos...         4725
# 27  Great coffee and friendly staff, will definite...         9464
# 28  Great coffee, friendly staff.  I usually get t...         7084
# 29  service was fast even during peak hours.  comf...         4585
# 30  I enjoyed my fresh brewed coffee.  The barista...         5634
# 31  The service at this location was great. The st...         4433
# 32  Good service with a short wait time. The coffe...         1854
# 33  The coffee was too strong for my taste and it ...         4034
# 34  I had a great experience at this coffee truck....         6867
# 35  The cozy seating areas and quiet location prov...        10230
# 36  I had a great experience at this location! The...         8399
# 37  The baristas were incredibly rude to me for no...         9745
# 38  The coffee was ok but the atmosphere was so re...         8118
# 39  I had a great experience at this coffee truck....         3615
# 40  I was very impressed with the cozy seating are...         9889
# 41  Very friendly and knowledgeable staff, cozy at...         1080
# 42  I had a great experience today! The barista wa...         3731
# 43  Great coffee, friendly staff a bit of a wait (...         1265
# 44                                       Great coffee         3498
# 45  Bad service and very overpriced. They seemed v...         7769
# 46  The coffee is strong and flavorful and the sta...         4840
# 47  I had a great experience at this coffee truck....         9432
# 48  This coffee truck is amazing! The staff are al...         2274
# 49  Great coffee, friendly staff, and cozy atmosph...         4938
#
#     location_id     review_datetime
# 0             1 2024-01-01 22:36:10
# 1             1 2024-01-07 19:58:10
# 2             1 2024-01-10 00:05:10
# 3             1 2024-01-13 12:22:10
# 4             1 2024-01-16 20:00:10
# 5             1 2024-01-24 04:24:10
# 6             1 2024-01-28 23:27:10
# 7             1 2024-02-05 15:41:10
# 8             1 2024-02-05 18:02:10
# 9             1 2024-02-06 10:23:10
# 10            1 2024-02-12 09:03:10
# 11            1 2024-02-15 21:02:10
# 12            1 2024-02-18 07:00:10
# 13            1 2024-03-08 05:29:10
# 14            1 2024-03-10 07:42:10
# 15            1 2024-03-10 23:41:10
# 16            1 2024-03-27 04:15:10
# 17            1 2024-03-27 22:44:10
# 18            1 2024-04-07 13:59:10
# 19            1 2024-04-10 00:33:10
# 20            1 2024-04-11 08:15:10
# 21            1 2024-04-18 06:39:10
# 22            1 2024-05-01 14:39:10
# 23            1 2024-05-02 06:35:10
# 24            1 2024-05-02 15:46:10
# 25            1 2024-05-11 21:20:10
# 26            1 2024-05-14 03:09:10
# 27            1 2024-05-15 23:07:10
# 28            1 2024-06-01 11:59:10
# 29            1 2024-06-04 20:26:10
# 30            1 2024-06-07 07:48:10
# 31            1 2024-06-26 10:23:10
# 32            1 2024-07-13 23:57:10
# 33            1 2024-07-25 03:20:10
# 34            1 2024-08-01 07:13:10
# 35            1 2024-08-21 05:10:10
# 36            1 2024-09-06 15:07:10
# 37            1 2024-09-09 20:26:10
# 38            1 2024-09-16 10:26:10
# 39            1 2024-09-29 13:24:10
# 40            1 2024-10-02 12:17:10
# 41            1 2024-10-15 16:09:10
# 42            1 2024-10-31 03:40:10
# 43            1 2024-11-02 02:17:10
# 44            1 2024-11-10 12:57:10
# 45            1 2024-11-13 00:09:10
# 46            1 2024-11-15 03:47:10
# 47            1 2024-11-26 00:59:10
# 48            1 2024-12-26 11:43:10
# 49            1 2024-12-30 07:02:10

# %%
# Task 6.5 - Create the BigQuery client, and query the cleaned data view for positive and negative reviews, store the results in a dataframe and then show the first 10 records
client = bigquery.Client()
query = "SELECT sentiment, COUNT(*) AS count FROM `gemini_demo.cleaned_data_view` WHERE sentiment IN ('positive', 'negative') GROUP BY sentiment;"
query_job = client.query(query)
results = query_job.result().to_dataframe()
results.head(10)
# Out:
#   sentiment  count
# 0  positive     38
# 1  negative      9

# %%
# Define variable for the report.
sentiment = results["sentiment"].tolist()
count = results["count"].tolist()

# %%
# Task 6.7 - Build the report.
plt.bar(sentiment, count, color='skyblue')
plt.xlabel("Sentiment")
plt.ylabel("Total Count")
plt.title("Bar Chart from BigQuery Data")
plt.show()

# %%
# Create an HTML table for the counts of negative and positive sentiment and color codes the results.
html_counts = f"""
<table style="border-collapse:collapse;width:25%;padding:10px;">

<tbody><tr style="background-color:#f2f2f2;">
<th style="padding:10px;text-align:left;">Negative</th>
<th style="padding:10px;text-align:left;">Positive</th>
</tr>


<tr style="padding:10px;">
<td style="padding:10px;color:red;">{count[0]}</td>
<td style="padding:10px;color:green;">{count[1]}</td>
</tr>

</tbody></table>
"""

# Display the HTML tables
display(HTML(html_counts))
# Out:
# <table style="border-collapse:collapse;width:25%;padding:10px;">
#
# <tbody><tr style="background-color:#f2f2f2;">
# <th style="padding:10px;text-align:left;">Negative</th>
# <th style="padding:10px;text-align:left;">Positive</th>
# </tr>
#
#
# <tr style="padding:10px;">
# <td style="padding:10px;color:red;">38</td>
# <td style="padding:10px;color:green;">9</td>
# </tr>
#
# </tbody></table>

# %%
# Conduct sentiment analysis on audio files and respond to the customer.
vertexai.init(project="qwiklabs-gcp-02-5c9e576b4dbf", location="us-central1")

model = GenerativeModel(model_name="gemini-1.5-flash")

prompt = """
Please provide a transcript for the audio.
Then provide a summary for the audio.
Then identify the keywords in the transcript.
Be concise and short.
Do not make up any information that is not part of the audio and do not be verbose.
Then determine the sentiment of the audio: positive, neutral or negative.

Also, you are a customr service representative.
How would you respond to this customer review?
From the customer reviews provide actions that the location can take to improve. The response and the actions should be simple, and to the point. Do not include any extraneous characters in your response.
Answer in JSON format with five keys: transcript, summary, keywords, sentiment, response and actions. Transcript should be a string, summary should be a sting, keywords should be a list, sentiment should be a string, customer response should be a string and actions should be string.
"""

bucket_name = "qwiklabs-gcp-02-5c9e576b4dbf-bucket"
folder_name = 'gsp1249/audio'  # Include the trailing '/'

def list_mp3_files(bucket_name, folder_name):
   storage_client = storage.Client()
   bucket = storage_client.bucket(bucket_name)
   print('Accessing ', bucket, ' with ', storage_client)

   blobs = bucket.list_blobs(prefix=folder_name)

   mp3_files = []
   for blob in blobs:
      if blob.name.endswith('.mp3'):
            mp3_files.append(blob.name)
   return mp3_files

file_names = list_mp3_files(bucket_name, folder_name)
if file_names:
   print("MP3 files found:")
   print(file_names)
   for file_name in file_names:
      audio_file_uri = f"gs://{bucket_name}/{file_name}"
      print('Processing file at ', audio_file_uri)
      audio_file = Part.from_uri(audio_file_uri, mime_type="audio/mpeg")
      contents = [audio_file, prompt]
      response = model.generate_content(contents)
      print(response.text)
else:
   print("No MP3 files found in the specified folder.")
# Out:
# Accessing  <Bucket: qwiklabs-gcp-02-5c9e576b4dbf-bucket>  with  <google.cloud.storage.client.Client object at 0x7ab679268f10>
# MP3 files found:
# ['gsp1249/audio/data-beans_review_1395.mp3', 'gsp1249/audio/data-beans_review_2199.mp3', 'gsp1249/audio/data-beans_review_2763.mp3', 'gsp1249/audio/data-beans_review_2884.mp3', 'gsp1249/audio/data-beans_review_7061.mp3']
# Processing file at  gs://qwiklabs-gcp-02-5c9e576b4dbf-bucket/gsp1249/audio/data-beans_review_1395.mp3
# ```json
# {
#   "transcript": "Great place. The coffee is always good and the service is quick and friendly.",
#   "summary": "The customer had a positive experience at the location, praising the coffee and the friendly service.",
#   "keywords": ["great", "coffee", "good", "service", "quick", "friendly"],
#   "sentiment": "positive",
#   "response": "Thank you for your kind words! We're so glad you enjoyed your coffee and our service. We strive to make every visit a great one.",
#   "actions": "Continue to maintain high coffee quality and friendly service."
# }
# ```
# Processing file at  gs://qwiklabs-gcp-02-5c9e576b4dbf-bucket/gsp1249/audio/data-beans_review_2199.mp3
# ```json
# {
#  "transcript": "Overcrowded and overpriced with inconsistent quality. No flavor for how expensive each drink is.",
#  "summary": "The customer is complaining about the overcrowded and overpriced establishment with inconsistent drink quality and a lack of flavor for the high price.",
#  "keywords": ["overcrowded", "overpriced", "inconsistent quality", "no flavor", "expensive"],
#  "sentiment": "negative",
#  "response": "Thank you for sharing your feedback. We appreciate your honesty and will look into your concerns regarding the quality and pricing of our drinks. We strive to provide a positive experience for all of our customers and will take your comments seriously. ",
#  "actions": "The location could consider reducing overcrowding, reviewing their pricing strategy,  implementing quality control measures and improving the flavor profiles of their drinks."
# }
# ```
# Processing file at  gs://qwiklabs-gcp-02-5c9e576b4dbf-bucket/gsp1249/audio/data-beans_review_2763.mp3
# ```json
# {
#  "transcript": "The location was close to my home so I decided to try it out The drinks did not disappoint and were so tasty I am happy that I found this place to get coffee now",
#  "summary": "The customer was happy with the coffee and the location of the cafe. They were glad to have found a new place for coffee.",
#  "keywords": [
#   "location",
#   "home",
#   "drinks",
#   "tasty",
#   "coffee",
#   "place"
#  ],
#  "sentiment": "positive",
#  "response": "Thank you for your kind words! We're thrilled you enjoyed our coffee and the location. We strive to provide a delicious and convenient experience for our customers.",
#  "actions": "Continue to offer tasty drinks and maintain the convenient location."
# }
# ```
# Processing file at  gs://qwiklabs-gcp-02-5c9e576b4dbf-bucket/gsp1249/audio/data-beans_review_2884.mp3
# {
#  "transcript": "The staff was very friendly and the coffee was great I would definitely recommend this place to anyone looking for a good cup of coffee",
#  "summary": "The customer had a positive experience at the coffee shop, praising the friendly staff and the quality of the coffee.",
#  "keywords": ["staff", "friendly", "coffee", "great", "recommend"],
#  "sentiment": "positive",
#  "response": "Thank you for your kind words! We're thrilled to hear you enjoyed your coffee and our staff. We strive to provide a welcoming atmosphere and delicious brews, and we're glad we hit the mark for you.",
#  "actions": "Continue to provide excellent customer service and maintain the quality of the coffee."
# }
#
# Processing file at  gs://qwiklabs-gcp-02-5c9e576b4dbf-bucket/gsp1249/audio/data-beans_review_7061.mp3
# ```json
# {
#  "transcript": "Coffee was too milky, not the right temperature, and not enough seating.",
#  "summary": "The customer was unhappy with their coffee because it was too milky, not the right temperature, and the cafe lacked seating.",
#  "keywords": [
#   "coffee",
#   "milky",
#   "temperature",
#   "seating"
#  ],
#  "sentiment": "negative",
#  "response": "Thank you for your feedback! We are sorry to hear that your coffee wasn't to your liking. We will work on improving our coffee preparation and seating arrangements. We value your feedback and strive to improve our service.",
#  "actions": "Train baristas on proper coffee preparation, ensure optimal temperature, and increase seating capacity."
# }
# ```

# %%
# Generate the transcript for the negative review audio file, create the JSON object, and associated variables

audio_file_uri = f"gs://{bucket_name}/{folder_name}/data-beans_review_7061.mp3"
print(audio_file_uri)

audio_file = Part.from_uri(audio_file_uri, mime_type="audio/mpeg")

contents = [audio_file, prompt]

response = model.generate_content(contents)
print('Generating Transcript...')
#print(response.text)

results = response.text
# print("your results are", results, type(results))
print('Transcript created...')

print('Transcript ready for analysis...')

json_data = results.replace('```json', '')
json_data = json_data.replace('```', '')
jason_data = '"""' + results + '"""'

# print(json_data, type(json_data))

data = json.loads(json_data)

# print(data)

transcript = data["transcript"]
summary = data["summary"]
sentiment = data["sentiment"]
keywords = data["keywords"]
response = data["response"]
actions = data["actions"]
# Out:
# gs://qwiklabs-gcp-02-5c9e576b4dbf-bucket/gsp1249/audio/data-beans_review_7061.mp3
# Generating Transcript...
# Transcript created...
# Transcript ready for analysis...

# %%
# Create an HTML table (including the image) from the selected values.

html_string = f"""
<table style="border-collapse:collapse;width:100%;padding:10px;">
<tbody><tr style="background-color:#f2f2f2;">
<th style="padding:10px;width:50%;text-align:left;">customer_id: 7061 - @coffee_lover789</th>
<th style="padding:10px;width:50%;text-align:left;">&nbsp;</th>
</tr>
</tbody></table>
<table>

<tbody><tr style="padding:10px;">
<td style="padding:10px;">{transcript}</td>
<td style="padding:10px;color:red;">{sentiment} feedback</td>
</tr>
<tr>
</tr>
<tr style="padding:10px;">
<td style="padding:10px;">&nbsp;</td>
<td style="padding:10px;">
<table>

<tbody><tr><td>{keywords[0]}</td></tr>
<tr><td>{keywords[1]}</td></tr>
<tr><td>{keywords[2]}</td></tr>
<tr><td>{keywords[3]}</td></tr>

</tbody></table>
</td>
</tr>
<tr style="padding:10px;">
<td style="padding:10px;">
<strong>Customer summary:</strong>{summary}</td>
</tr>
<tr style="padding:10px;">
<td style="padding:10px;">
<strong>Recommended actions:</strong>{actions}</td>
</tr>
<tr style="padding:10px;">
<td style="padding:10px;background-color:#EAE0CF;">
<strong>Suggested Response:</strong>{response}</td>
</tr>

</tbody></table>

"""
print('The table has been created.')
# Out:
# The table has been created.

# %%
# Download the audio file from Google Cloud Storage and load into the player
storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(f"{folder_name}/data-beans_review_7061.mp3")
audio_bytes = io.BytesIO(blob.download_as_bytes())

# Assuming a sample rate of 44100 Hz (common for MP3 files)
sample_rate = 44100

print('The audio file is loaded in the player.')
# Out:
# The audio file is loaded in the player.

# %%
# Task 7.5 - Build the mockup as output to the cell.
print('Analysis complete. Review the results below.')
display(HTML(html_string))
display(Audio(audio_bytes.read(), rate=sample_rate, autoplay=True))
# Out:
# Analysis complete. Review the results below.
# <table style="border-collapse:collapse;width:100%;padding:10px;">
# <tbody><tr style="background-color:#f2f2f2;">
# <th style="padding:10px;width:50%;text-align:left;">customer_id: 7061 - @coffee_lover789</th>
# <th style="padding:10px;width:50%;text-align:left;">&nbsp;</th>
# </tr>
# </tbody></table>
# <table>
#
# <tbody><tr style="padding:10px;">
# <td style="padding:10px;">Coffee was too milky, not the right temperature, and not enough seating.</td>
# <td style="padding:10px;color:red;">negative feedback</td>
# </tr>
# <tr>
# </tr>
# <tr style="padding:10px;">
# <td style="padding:10px;">&nbsp;</td>
# <td style="padding:10px;">
# <table>
#
# <tbody><tr><td>coffee</td></tr>
# <tr><td>milky</td></tr>
# <tr><td>temperature</td></tr>
# <tr><td>seating</td></tr>
#
# </tbody></table>
# </td>
# </tr>
# <tr style="padding:10px;">
# <td style="padding:10px;">
# <strong>Customer summary:</strong>The customer was unhappy with the coffee, its temperature and the lack of seating.</td>
# </tr>
# <tr style="padding:10px;">
# <td style="padding:10px;">
# <strong>Recommended actions:</strong>Review and adjust coffee brewing process, review temperature settings for coffee machines, investigate options for additional seating.</td>
# </tr>
# <tr style="padding:10px;">
# <td style="padding:10px;background-color:#EAE0CF;">
# <strong>Suggested Response:</strong>Thank you for your feedback. We are always striving to improve. We will look into the coffee and temperature issues. We are aware of the seating limitations and are working on a solution.</td>
# </tr>
#
# </tbody></table>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
